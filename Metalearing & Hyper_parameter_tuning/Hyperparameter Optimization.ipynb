# %%
import numpy as np
import pandas as pd
#import time

from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.ensemble.forest import RandomForestRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error

from hyperopt import hp, space_eval, fmin, tpe, hp, STATUS_OK, Trials

# %% [markdown]
# ### Get Data and Split into Train/Test

# %%
df = pd.read_csv("../Dataset/heart_target.csv")

# %%
def split_df(df,target,val_size=0.3):
    X_lst = list(df.columns)
    X_lst.remove(target)
    X = df[X_lst]
    y = df[target]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=val_size)
    return X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = split_df(df, 'target')
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %% [markdown]
# ### Define param_space

# %%
rf_cls_param_space = {
    'max_depth': hp.choice('max_depth', range(1,20)),
    'max_features': hp.choice('max_features', range(1,len(X_train.columns))),
    'n_estimators': hp.choice('n_estimators', range(100,500)),
    'criterion': hp.choice('criterion', ["gini", "entropy"])}
rf_reg_param_space = {
    'max_depth': hp.choice('max_depth', range(1,20)),
    'max_features': hp.choice('max_features', range(1,len(X_train.columns))),
    'n_estimators': hp.choice('n_estimators', range(100,500)),
    'criterion': hp.choice('criterion', ["mse", "mae"])}

param_space = {'RandomForestClassifier':rf_cls_param_space,
               'RandomForestRegressor':rf_reg_param_space,
               
              }

# %% [markdown]
# ### Hyperparameter Tuning

# %%
'''
For this to work we need:
1. The algorithm object having .set_params method
2. str(algo_type).split('(')[0] Must return the name of the ObjectType
'''

################### For test
# algo_type = RandomForestClassifier()
# task_type = 'cls'
algo_type = RandomForestRegressor() #주어질 것
task_type = 'reg'                   #정해질 것
################################

# %%
def score_model_classification(model,params):
    return -1*cross_val_score(model.set_params(**params),X_train,y_train,cv=5,scoring='f1').mean()
def score_model_regression(model,params):
    ### cross_val_score()reuturns negative mse
    return -1 - cross_val_score(model.set_params(**params),X_train,y_train,cv=5,scoring='neg_mean_squared_error').mean()

def f_cls(params):
    score = score_model_classification(algo_type,params)
    print('score config (-f1):', score, params)
    return {'loss': score, 'status': STATUS_OK}
def f_reg(params):
    score = score_model_regression(algo_type,params)
    print('score config (-1 + mse):', score, params)
    return {'loss': score, 'status': STATUS_OK}


trials = Trials()
if task_type == 'reg':
    best = fmin(f_reg, param_space[str(algo_type).split('(')[0]], algo=tpe.suggest, max_evals=100, trials=trials)
elif task_type == 'cls':
    best = fmin(f_cls, param_space[str(algo_type).split('(')[0]], algo=tpe.suggest, max_evals=100, trials=trials)
print ('best:')
print (best)
# Out:
# score config:
# -0.8518204682800099
# {'criterion': 'mse', 'max_depth': 12, 'max_features': 11, 'n_estimators': 327}
# score config:
# -0.850614042772778
# {'criterion': 'mae', 'max_depth': 5, 'max_features': 7, 'n_estimators': 230}
# score config:
# -0.8529378281223051
# {'criterion': 'mae', 'max_depth': 17, 'max_features': 4, 'n_estimators': 209}
# score config:
# -0.8568304181120547
# {'criterion': 'mae', 'max_depth': 1, 'max_features': 5, 'n_estimators': 343}
# score config:
# -0.8531597968844974
# {'criterion': 'mse', 'max_depth': 17, 'max_features': 9, 'n_estimators': 307}
# score config:
# -0.8470001062411161
# {'criterion': 'mae', 'max_depth': 6, 'max_features': 10, 'n_estimators': 230}
# score config:
# -0.8553944184567333
# {'criterion': 'mae', 'max_depth': 3, 'max_features': 7, 'n_estimators': 259}
# score config:
# -0.8493892674111168
# {'criterion': 'mae', 'max_depth': 17, 'max_features': 11, 'n_estimators': 307}
# score config:
# -0.8629239970504119
# {'criterion': 'mse', 'max_depth': 12, 'max_features': 3, 'n_estimators': 412}
# score config:
# -0.8565806617212552
# {'criterion': 'mae', 'max_depth': 8, 'max_features': 1, 'n_estimators': 108}
# score config:
# -0.8607019233269864
# {'criterion': 'mae', 'max_depth': 10, 'max_features': 2, 'n_estimators': 232}
# score config:
# -0.8250708807738909
# {'criterion': 'mse', 'max_depth': 1, 'max_features': 5, 'n_estimators': 179}
# score config:
# -0.8555689952130816
# {'criterion': 'mse', 'max_depth': 15, 'max_features': 6, 'n_estimators': 484}
# score config:
# -0.8472950785187284
# {'criterion': 'mae', 'max_depth': 8, 'max_features': 12, 'n_estimators': 254}
# score config:
# -0.857536515498571
# {'criterion': 'mae', 'max_depth': 15, 'max_features': 2, 'n_estimators': 267}
# score config:
# -0.8496323461613488
# {'criterion': 'mse', 'max_depth': 2, 'max_features': 8, 'n_estimators': 417}
# score config:
# -0.8584501252051041
# {'criterion': 'mse', 'max_depth': 19, 'max_features': 5, 'n_estimators': 482}
# score config:
# -0.8470136988386273
# {'criterion': 'mae', 'max_depth': 11, 'max_features': 11, 'n_estimators': 362}
# score config:
# -0.8513452856028885
# {'criterion': 'mse', 'max_depth': 15, 'max_features': 11, 'n_estimators': 182}
# score config:
# -0.8562273137813871
# {'criterion': 'mse', 'max_depth': 8, 'max_features': 4, 'n_estimators': 178}
# score config:
# -0.8598400724069878
# {'criterion': 'mse', 'max_depth': 10, 'max_features': 3, 'n_estimators': 439}
# score config:
# -0.8627054226295742
# {'criterion': 'mse', 'max_depth': 10, 'max_features': 2, 'n_estimators': 232}
# score config:
# -0.8596069927839864
# {'criterion': 'mse', 'max_depth': 12, 'max_features': 3, 'n_estimators': 374}
# score config:
# -0.8633031959211785
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 460}
# score config:
# -0.8592654207455315
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 3, 'n_estimators': 339}
# score config:
# -0.8512688035189153
# {'criterion': 'mse', 'max_depth': 16, 'max_features': 10, 'n_estimators': 312}
# score config:
# -0.8617239352839992
# {'criterion': 'mse', 'max_depth': 14, 'max_features': 2, 'n_estimators': 447}
# score config:
# -0.8613430441553209
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 3, 'n_estimators': 119}
# score config:
# -0.8629891584493574
# {'criterion': 'mse', 'max_depth': 9, 'max_features': 1, 'n_estimators': 329}
# score config:
# -0.8627247534525904
# {'criterion': 'mse', 'max_depth': 9, 'max_features': 1, 'n_estimators': 441}
# score config:
# -0.8582396947314431
# {'criterion': 'mse', 'max_depth': 7, 'max_features': 1, 'n_estimators': 118}
# score config:
# -0.8559104343926927
# {'criterion': 'mse', 'max_depth': 9, 'max_features': 6, 'n_estimators': 298}
# score config:
# -0.8534355483548164
# {'criterion': 'mse', 'max_depth': 4, 'max_features': 12, 'n_estimators': 235}
# score config:
# -0.8558061186822459
# {'criterion': 'mse', 'max_depth': 13, 'max_features': 9, 'n_estimators': 210}
# score config:
# -0.8622456813559809
# {'criterion': 'mse', 'max_depth': 9, 'max_features': 1, 'n_estimators': 459}
# score config:
# -0.8564935199819128
# {'criterion': 'mse', 'max_depth': 6, 'max_features': 8, 'n_estimators': 193}
# score config:
# -0.8588353862593168
# {'criterion': 'mse', 'max_depth': 5, 'max_features': 4, 'n_estimators': 137}
# score config:
# -0.8567084500539992
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 7, 'n_estimators': 446}
# score config:
# -0.8593478946606926
# {'criterion': 'mse', 'max_depth': 3, 'max_features': 9, 'n_estimators': 319}
# score config:
# -0.8609420474407772
# {'criterion': 'mae', 'max_depth': 9, 'max_features': 1, 'n_estimators': 244}
# score config:
# -0.8631424957573783
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 435}
# score config:
# -0.8591459183728211
# {'criterion': 'mae', 'max_depth': 18, 'max_features': 2, 'n_estimators': 425}
# score config:
# -0.8623712409511192
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 433}
# score config:
# -0.8617540751345438
# {'criterion': 'mae', 'max_depth': 17, 'max_features': 2, 'n_estimators': 428}
# score config:
# -0.823413672120977
# {'criterion': 'mse', 'max_depth': 1, 'max_features': 10, 'n_estimators': 305}
# score config:
# -0.8505613569691243
# {'criterion': 'mse', 'max_depth': 2, 'max_features': 7, 'n_estimators': 203}
# score config:
# -0.8604552882034562
# {'criterion': 'mae', 'max_depth': 19, 'max_features': 2, 'n_estimators': 435}
# score config:
# -0.8569660859365691
# {'criterion': 'mse', 'max_depth': 11, 'max_features': 6, 'n_estimators': 146}
# score config:
# -0.8570250188975139
# {'criterion': 'mse', 'max_depth': 7, 'max_features': 5, 'n_estimators': 431}
# score config:
# -0.8425064564575145
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 12, 'n_estimators': 457}
# score config:
# -0.8631166612665231
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 306}
# score config:
# -0.8529621650561638
# {'criterion': 'mse', 'max_depth': 14, 'max_features': 11, 'n_estimators': 206}
# score config:
# -0.8511732006757812
# {'criterion': 'mae', 'max_depth': 13, 'max_features': 8, 'n_estimators': 281}
# score config:
# -0.8611062281567915
# {'criterion': 'mse', 'max_depth': 5, 'max_features': 4, 'n_estimators': 384}
# score config:
# -0.8613921920130179
# {'criterion': 'mse', 'max_depth': 16, 'max_features': 2, 'n_estimators': 175}
# score config:
# -0.8528558786775735
# {'criterion': 'mse', 'max_depth': 12, 'max_features': 10, 'n_estimators': 472}
# score config:
# -0.8563414217887445
# {'criterion': 'mae', 'max_depth': 6, 'max_features': 5, 'n_estimators': 460}
# score config:
# -0.8557664981679334
# {'criterion': 'mse', 'max_depth': 3, 'max_features': 2, 'n_estimators': 406}
# score config:
# -0.8534819278823746
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 9, 'n_estimators': 492}
# score config:
# -0.8547502216780606
# {'criterion': 'mse', 'max_depth': 8, 'max_features': 7, 'n_estimators': 112}
# score config:
# -0.8459068671012608
# {'criterion': 'mae', 'max_depth': 15, 'max_features': 12, 'n_estimators': 460}
# score config:
# -0.8568455865181067
# {'criterion': 'mse', 'max_depth': 17, 'max_features': 6, 'n_estimators': 105}
# score config:
# -0.8527846701381145
# {'criterion': 'mse', 'max_depth': 19, 'max_features': 11, 'n_estimators': 353}
# score config:
# -0.8160746388930893
# {'criterion': 'mse', 'max_depth': 1, 'max_features': 2, 'n_estimators': 122}
# score config:
# -0.8544905998721248
# {'criterion': 'mse', 'max_depth': 10, 'max_features': 8, 'n_estimators': 202}
# score config:
# -0.8594008726215678
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 261}
# score config:
# -0.8641139474464538
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 422}
# score config:
# -0.8628776514942074
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 461}
# score config:
# -0.862167987667888
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 409}
# score config:
# -0.8501633582194471
# {'criterion': 'mse', 'max_depth': 2, 'max_features': 4, 'n_estimators': 407}
# score config:
# -0.8610900635407448
# {'criterion': 'mse', 'max_depth': 11, 'max_features': 2, 'n_estimators': 348}
# score config:
# -0.8615389198073042
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 3, 'n_estimators': 387}
# score config:
# -0.8628469400880787
# {'criterion': 'mse', 'max_depth': 14, 'max_features': 2, 'n_estimators': 352}
# score config:
# -0.8501131445191085
# {'criterion': 'mse', 'max_depth': 16, 'max_features': 9, 'n_estimators': 201}
# score config:
# -0.8551540454225535
# {'criterion': 'mse', 'max_depth': 7, 'max_features': 10, 'n_estimators': 435}
# score config:
# -0.8608025475229493
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 5, 'n_estimators': 220}
# score config:
# -0.8590973700402046
# {'criterion': 'mse', 'max_depth': 4, 'max_features': 2, 'n_estimators': 479}
# score config:
# -0.8546039686840561
# {'criterion': 'mae', 'max_depth': 6, 'max_features': 6, 'n_estimators': 388}
# score config:
# -0.8540017882146278
# {'criterion': 'mse', 'max_depth': 12, 'max_features': 7, 'n_estimators': 141}
# score config:
# -0.8515613779172764
# {'criterion': 'mse', 'max_depth': 13, 'max_features': 11, 'n_estimators': 268}
# score config:
# -0.8498451002894317
# {'criterion': 'mse', 'max_depth': 5, 'max_features': 12, 'n_estimators': 124}
# score config:
# -0.8614102306460221
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 2, 'n_estimators': 157}
# score config:
# -0.8585826768872344
# {'criterion': 'mae', 'max_depth': 8, 'max_features': 3, 'n_estimators': 422}
# score config:
# -0.8548826372064156
# {'criterion': 'mse', 'max_depth': 15, 'max_features': 8, 'n_estimators': 181}
# score config:
# -0.8409007824272969
# {'criterion': 'mse', 'max_depth': 3, 'max_features': 1, 'n_estimators': 421}
# score config:
# -0.8572433523087631
# {'criterion': 'mse', 'max_depth': 10, 'max_features': 4, 'n_estimators': 149}
# score config:
# -0.8594392286452566
# {'criterion': 'mae', 'max_depth': 18, 'max_features': 2, 'n_estimators': 375}
# score config:
# -0.8557183554817276
# {'criterion': 'mse', 'max_depth': 17, 'max_features': 10, 'n_estimators': 200}
# score config:
# -0.8160630219649425
# {'criterion': 'mse', 'max_depth': 1, 'max_features': 2, 'n_estimators': 364}
# score config:
# -0.8502741352527488
# {'criterion': 'mse', 'max_depth': 2, 'max_features': 9, 'n_estimators': 241}
# score config:
# -0.8552886763360106
# {'criterion': 'mae', 'max_depth': 19, 'max_features': 5, 'n_estimators': 214}
# score config:
# -0.8620993620279549
# {'criterion': 'mse', 'max_depth': 11, 'max_features': 2, 'n_estimators': 383}
# score config:
# -0.8556238816818379
# {'criterion': 'mse', 'max_depth': 18, 'max_features': 7, 'n_estimators': 153}
# score config:
# -0.8545972714768042
# {'criterion': 'mse', 'max_depth': 7, 'max_features': 6, 'n_estimators': 369}
# score config:
# -0.8505893066300848
# {'criterion': 'mse', 'max_depth': 16, 'max_features': 12, 'n_estimators': 204}
# score config:
# -0.8639864794202605
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 2, 'n_estimators': 216}
# score config:
# -0.8473719834348468
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 11, 'n_estimators': 120}
# score config:
# -0.8613964623584074
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 1, 'n_estimators': 165}
# score config:
# -0.8490749232240269
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 8, 'n_estimators': 216}
# score config:
# -0.863257990776485
# {'criterion': 'mae', 'max_depth': 4, 'max_features': 2, 'n_estimators': 291}
# 100%|████████████████████████████████████████████████| 100/100 [02:01<00:00,  1.07s/it, best loss: -0.8641139474464538]
# best:
# {'criterion': 0, 'max_depth': 17, 'max_features': 1, 'n_estimators': 322}

# %% [markdown]
# ### Train Model with optimized Hyperparameters

# %%
params = space_eval(param_space[str(algo_type).split('(')[0]],best)
algo_type.set_params(**params)
algo_type.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=18,
#            max_features=2, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=422, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ### Final Evaluation

# %%
def test_classification(model,params):
    y_pred = model.predict(X_test)
    return y_pred, f1_score(y_test, y_pred)
def test_regression(model,params):
    y_pred = model.predict(X_test)
    return y_pred, mean_squared_error(y_test, y_pred)

# %%
if task_type == 'cls':
    res,f1_score = test_classification(algo_type, best)
    print(res,f1_score)
else:
    res,mse = test_regression(algo_type,best)
    print(res,mse)
# Out:
# [0.90995261 0.5521327  0.68957346 0.03317536 0.66824645 0.48341232
#  0.80805687 0.12796209 0.09952607 0.59004739 0.04976303 0.8056872
#  0.97630332 0.10900474 0.92417062 0.87440758 0.61848341 0.51895735
#  0.98341232 0.68483412 0.17535545 0.96445498 0.83175355 0.69905213
#  0.56398104 0.8056872  0.38151659 0.6943128  0.8436019  0.90758294
#  0.05687204 0.75829384 0.40521327 0.992891   0.68720379 0.7985782
#  0.39099526 0.47156398 0.44075829 0.18246445 0.34834123 0.62559242
#  0.51895735 0.13981043 0.42890995 0.9549763  0.90047393 0.8436019
#  0.58293839 0.08056872 0.68483412 0.09952607 0.90758294 0.59952607
#  0.77014218 0.0971564  0.57345972 0.44312796 0.91232227 0.76540284
#  0.59241706 0.68246445 0.53080569 0.69905213 0.20616114 0.32938389
#  0.61848341 0.96445498 0.00236967 0.53317536 0.31279621 0.9478673
#  0.62559242 0.507109   0.01184834 0.06635071 0.88862559 0.23696682
#  0.38388626 0.88625592 0.4028436  0.76066351 0.71327014 0.84597156
#  0.88388626 0.12085308 0.59241706 0.93838863 0.2464455  0.51895735
#  0.6563981 ] 0.1122393531537531

# %%
#Final Evaluation
def test_classification(model,params):
    y_pred = model.predict(X_test)
    return y_pred, f1_score(y_test, y_pred)
def test_regression(model,params):
    y_pred = model.predict(X_test)
    return y_pred, mean_squared_error(y_test, y_pred)

y_pred = None
if task_type == 'cls':
    y_pred, f1_score = test_classification(algo_type, best)
    print(f1_score)
else:
    y_pred, mse = test_regression(algo_type,best)
    print(mse)
return algo_type
# Out:
# 0.1122393531537531
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=18,
#            max_features=2, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=422, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)
